# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
games = pd.read_csv(r"C:\Users\kyrie\ironhack\Excel_CSV_file\nba\games.csv")
games
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2022-03-12  22101005            Final    1610612748       1610612750
# 1        2022-03-12  22101006            Final    1610612741       1610612739
# 2        2022-03-12  22101007            Final    1610612759       1610612754
# 3        2022-03-12  22101008            Final    1610612744       1610612749
# 4        2022-03-12  22101009            Final    1610612743       1610612761
# ...             ...       ...              ...           ...              ...
# 25791    2014-10-06  11400007            Final    1610612737       1610612740
# 25792    2014-10-06  11400004            Final    1610612741       1610612764
# 25793    2014-10-06  11400005            Final    1610612747       1610612743
# 25794    2014-10-05  11400002            Final    1610612761       1610612758
# 25795    2014-10-04  11400001            Final    1610612748       1610612740
#
# ...

# %%
games_sample = games.head(1000)
games_sample.to_csv(r"C:\Users\kyrie\ironhack\final_project\games_sample.csv")

# %%
games.loc[games.GAME_DATE_EST == '2021-10-03'] #first game of the 2021-2022 season
# Out:
#      GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 1075    2021-10-03  12100001            Final    1610612747       1610612751
#
#       SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 1075    2021    1610612747      97.0        0.364        0.688  ...      17.0
#
#       REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 1075      41.0    1610612751     123.0        0.483        0.725
#
#       FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 1075         0.417      20.0      54.0               0
#
# [1 rows x 21 columns]

# %%
games.shape
# Out:
# (25796, 21)

# %%
games.isna().sum().sort_values(ascending=False)
# Out:
# FG3_PCT_home        99
# REB_away            99
# AST_away            99
# FG3_PCT_away        99
# FT_PCT_away         99
# FG_PCT_away         99
# PTS_home            99
# FG_PCT_home         99
# FT_PCT_home         99
# PTS_away            99
# AST_home            99
# REB_home            99
# TEAM_ID_away         0
# GAME_DATE_EST        0
# GAME_ID              0
# TEAM_ID_home         0
# SEASON               0
# VISITOR_TEAM_ID      0
# HOME_TEAM_ID         0
# GAME_STATUS_TEXT     0
# HOME_TEAM_WINS       0
# dtype: int64

# %%
null_data = games[games.isnull().any(axis=1)]
null_data
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 18320    2003-10-24  10300116            Final    1610612753       1610612762
# 18321    2003-10-24  10300108            Final    1610612737       1610612764
# 18322    2003-10-24  10300109            Final    1610612738       1610612751
# 18323    2003-10-24  10300113            Final    1610612759       1610612745
# 18324    2003-10-24  10300112            Final    1610612749       1610612765
# ...             ...       ...              ...           ...              ...
# 18414    2003-10-09  10300019            Final    1610612743       1610612756
# 18415    2003-10-09  10300022            Final    1610612757       1610612758
# 18416    2003-10-08  10300013            Final    1610612759       1610612763
# 18423    2003-10-08  10300015            Final    1610612747       1610612744
# 18424    2003-10-07  10300006            Final    1610612747       1610612744
#
# ...

# %% [markdown]
# ## all the missing values are from the 2003 season

# %%
games.loc[games.SEASON > 2004]
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2022-03-12  22101005            Final    1610612748       1610612750
# 1        2022-03-12  22101006            Final    1610612741       1610612739
# 2        2022-03-12  22101007            Final    1610612759       1610612754
# 3        2022-03-12  22101008            Final    1610612744       1610612749
# 4        2022-03-12  22101009            Final    1610612743       1610612761
# ...             ...       ...              ...           ...              ...
# 25791    2014-10-06  11400007            Final    1610612737       1610612740
# 25792    2014-10-06  11400004            Final    1610612741       1610612764
# 25793    2014-10-06  11400005            Final    1610612747       1610612743
# 25794    2014-10-05  11400002            Final    1610612761       1610612758
# 25795    2014-10-04  11400001            Final    1610612748       1610612740
#
# ...

# %% [markdown]
# #

# %% [markdown]
# ### droping an uneccessary columns

# %%
games.GAME_STATUS_TEXT.value_counts()
# Out:
# Final    25796
# Name: GAME_STATUS_TEXT, dtype: int64

# %%
games = games.drop(['GAME_STATUS_TEXT'], axis=1)

# %% [markdown]
# # EDA

# %%
games.describe().T
# Out:
#                    count          mean           std           min  \
# GAME_ID          25796.0  2.169208e+07  5.496041e+06  1.030000e+07
# HOME_TEAM_ID     25796.0  1.610613e+09  8.638857e+00  1.610613e+09
# VISITOR_TEAM_ID  25796.0  1.610613e+09  8.654846e+00  1.610613e+09
# SEASON           25796.0  2.011798e+03  5.397985e+00  2.003000e+03
# TEAM_ID_home     25796.0  1.610613e+09  8.638857e+00  1.610613e+09
# PTS_home         25697.0  1.031060e+02  1.317473e+01  3.600000e+01
# FG_PCT_home      25697.0  4.603128e-01  5.662854e-02  2.500000e-01
# FT_PCT_home      25697.0  7.597049e-01  1.006920e-01  1.430000e-01
# FG3_PCT_home     25697.0  3.558964e-01  1.119400e-01  0.000000e+00
# AST_home         25697.0  2.273678e+01  5.177566e+00  6.000000e+00
# REB_home         25697.0  4.334580e+01  6.621832e+00  1.500000e+01
# TEAM_ID_away     25796.0  1.610613e+09  8.654846e+00  1.610613e+09
# PTS_away         25697.0  1.002941e+02  1.334302e+01  3.300000e+01
# ...

# %%
sns.heatmap(games.corr())
plt.title('correlation in the dataframe')
# Out:
# C:\Users\kyrie\AppData\Local\Temp\ipykernel_13116\2925292944.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(games.corr())
# Text(0.5, 1.0, 'correlation in the dataframe')

# %% [markdown]
# #  more win when a team play at Home

# %%
games.HOME_TEAM_WINS.value_counts()
# Out:
# 1    15155
# 0    10641
# Name: HOME_TEAM_WINS, dtype: int64

# %%
games.HOME_TEAM_WINS.value_counts().plot(kind= 'pie')
# Out:
# <AxesSubplot:ylabel='HOME_TEAM_WINS'>

# %%
games.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID', 'SEASON',
#        'TEAM_ID_home', 'PTS_home', 'FG_PCT_home', 'FT_PCT_home',
#        'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away', 'PTS_away',
#        'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away',
#        'HOME_TEAM_WINS'],
#       dtype='object')

# %%
box = games[['PTS_home','PTS_away','AST_home','AST_away','REB_home','REB_away']]

# %%
sns.boxplot(x="variable", y="value", data=pd.melt(box))

plt.show()

# %% [markdown]
# ### droping the outlier

# %%
games.loc[games.PTS_home < 47]
# Out:
#       GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 12777    2007-10-19  10700072    1610612738       1610612751    2007
#
#        TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# 12777    1610612738      36.0        0.414         0.75         0.375
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 12777       8.0      18.0    1610612751      33.0         0.29        0.722
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 12777         0.333       7.0      19.0               1

# %%
games.drop(games.loc[games.PTS_home == 36.0].index, inplace=True)

# %% [markdown]
# # per season

# %%
games.SEASON.value_counts().sort_index().plot(kind="bar",figsize=(11,5))
plt.title('total games per season')
# Out:
# Text(0.5, 1.0, 'total games per season')

# %%
games.groupby(['SEASON'], as_index = False)['PTS_home'].agg('mean')
# Out:
#     SEASON    PTS_home
# 0     2003   94.907465
# 1     2004   98.604993
# 2     2005   98.406425
# 3     2006   99.849190
# 4     2007  101.319858
# 5     2008  100.922807
# 6     2009  101.654494
# 7     2010  100.756681
# 8     2011   97.392210
# 9     2012   99.381690
# 10    2013  101.735109
# 11    2014  101.095205
# 12    2015  103.712571
# 13    2016  106.916014
# 14    2017  107.219971
# 15    2018  112.301887
# 16    2019  112.274778
# 17    2020  112.375500
# 18    2021  110.549257

# %%
games.groupby(['SEASON'])['PTS_home'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='SEASON'>

# %% [markdown]
# # we are working with the data starting in 2013

# %%
games2 = games.loc[games.SEASON > 2012]
games2
# Out:
#       GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 0        2022-03-12  22101005    1610612748       1610612750    2021
# 1        2022-03-12  22101006    1610612741       1610612739    2021
# 2        2022-03-12  22101007    1610612759       1610612754    2021
# 3        2022-03-12  22101008    1610612744       1610612749    2021
# 4        2022-03-12  22101009    1610612743       1610612761    2021
# ...             ...       ...           ...              ...     ...
# 25791    2014-10-06  11400007    1610612737       1610612740    2014
# 25792    2014-10-06  11400004    1610612741       1610612764    2014
# 25793    2014-10-06  11400005    1610612747       1610612743    2014
# 25794    2014-10-05  11400002    1610612761       1610612758    2014
# 25795    2014-10-04  11400001    1610612748       1610612740    2014
#
#        TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  \
# ...

# %%
games2.to_csv(r"C:\Users\kyrie\ironhack-Final-Project\final_project\cleangames.csv")
